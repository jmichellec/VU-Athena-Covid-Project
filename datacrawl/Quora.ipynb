# %%
import urllib
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://nl.quora.com/Waarom-zou-het-vaccin-tegen-corona-betrouwbaar-zijn-Er-kan-toch-zomaar-van-alles-in-gedaan-worden'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="nl">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <link href="https://qsf.fs.quoracdn.net/-4-images.favicon.ico-26-ebf6a9e7f7b4576d.ico" rel="icon"/>\n  <title>\n   Waarom zou het vaccin tegen corona betrouwbaar zijn? Er kan toch zomaar van alles in gedaan worden? - Quora\n  </title>\n  <meta content="noarchive" name="robots"/>\n  <meta content="light" name="twitter:widgets:theme"/>\n  <meta content="Dit is een argument dat je letterlijk voor alles kan zeggen, ik zal me even beperken tot wat ik zelf vaak gebruik: * Gemalen koffie * Melkpoeder * Oatmeal voor de baby * voorverpakte kaas * supermarkt-brood (nuja wat ze in de VS als brood benoemen..." name="description"/>\n  <link href="https://nl.quora.com/Waarom-zou-het-vaccin-tegen-corona-betrouwbaar-zijn-Er-kan-toch-zomaar-van-alles-in-gedaan-worden" rel="canonical"/>\n  <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ab
# ...

# %%
soup.find_all("div", {"class" : "pagedlist_item"})
# Out:
# []

# %%
soup.find('title').text.replace(" - Quora", "")
# Out:
# 'Waarom zou het vaccin tegen corona betrouwbaar zijn? Er kan toch zomaar van alles in gedaan worden?'

# %%
question = soup.find('title')

# %%
df = pd.DataFrame({'question': [], 'answers':[]})

# %%
for answer in answers:
     df = df.append({'question': question.text,
         'answers': answer.text
          }, ignore_index=True)
df
# Out:
# Empty DataFrame
# Columns: [question, answers]
# Index: []
